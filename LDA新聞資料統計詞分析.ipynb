# %% [markdown]
# <a href="https://colab.research.google.com/github/johnson880831/text-mining/blob/main/LDA%E6%96%B0%E8%81%9E%E8%B3%87%E6%96%99%E7%B5%B1%E8%A8%88%E8%A9%9E%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# coding:utf-8
__author__ = "liuxuejiang"
import jieba
import jieba.posseg as pseg
import os
import sys
import math
import json
from collections import OrderedDict

from sklearn import feature_extraction
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
class Data():
    def __init__(self):
        self.docs = {}
        self.seg_docs = self.get_seg_docs()
        self.stopword = []

    def read_file(self, path, type):
        # file.read([size])从文件读取指定的字节数，如果未给定或为负则读取所有。
        if type == 'json':
            with open('ettoday.news.json', 'r', encoding='utf-8') as file:
                data = json.loads(file.read())
        elif type == 'txt':
            with open('stopword.txt', 'r', encoding='utf-8') as file:
                data = file.read()
        return data

    def get_seg_docs(self):
        _seg_docs = []
        FOLDER_NAME = 'data'
        # DOCUMENT = 'test.json'
        DOCUMENT = 'ettoday.news.json'
        STOPWORD = 'stopword.txt'
        # 其中__file__虽然是所在.py文件的完整路径，但是这个变量有时候返回相对路径，有时候返回绝对路径，因此还要用os.path.realpath()函数来处理一下。
        # 获取当前文件__file__的路径，    __file__是当前执行的文件
        FILE_DIR = os.path.join(os.path.split(os.path.realpath('ettoday.news.json'))[0], FOLDER_NAME)
        
        self.docs = self.read_file(FILE_DIR + '/' + DOCUMENT, 'json')
        self.stopword = self.read_file(FILE_DIR + '/' + STOPWORD, 'txt')
        self.ca = []
        # jieba.cut 以及 jieba.cut_for_search 返回的结构都是一个可迭代的 generator，可以使用 for 循环来获得分词后得到的每一个词语(unicode)，或者用
        # jieba.lcut 以及 jieba.lcut_for_search 直接返回 list
        # isalpha()去除不是字母組成的字，中文字也算，e.g:\r\n，不然會斷出\r\n
        for i in range(len(self.docs)):
            # 計算幾個類別
            # self.ca.append(self.docs[i]['category'])
            content_str = ''
            # content_seg = []
            for w in jieba.lcut(self.docs[i]['content']):
                if len(w) > 1 and w not in self.stopword and w.isalpha():
                    content_str = content_str+' '+w
                    # content_seg.append(w)
            _seg_docs.append(content_str)
        # print(self.ca)
        # category = list(set(self.ca))
        # print(category)
        return _seg_docs

if __name__ == '__main__':
    data = Data()
    # print(data.seg_docs)
    # corpus = ["我 来到 北京 清华大学",  # 第一类文本切词后的结果，词之间以空格隔开
    #           "他 来到 了 网易 杭研 大厦",  # 第二类文本的切词结果
    #           "小明 硕士 毕业 与 中国 科学院",  # 第三类文本的切词结果
    #           "我 爱 北京 天安门"]  # 第四类文本的切词结果
    corpus = data.seg_docs
    # 將文本中的詞語，轉換成詞頻矩陣
    vectorizer = CountVectorizer()
    # print(vectorizer)
    # 計算詞語出現的頻率
    tf = vectorizer.fit_transform(corpus)
    # print("###################################")
    # 獲取詞袋中所有文本關鍵字，詞袋中所有的字詞
    words = vectorizer.get_feature_names()
    # print(words)
    # print("###################################")
    # print(tf)

    lda = LatentDirichletAllocation(n_components=100, learning_offset=50., random_state=0)
    docres = lda.fit_transform(tf)
    # print("###################################")
    # 文檔-主題分佈矩陣
    print(docres)
    # print("###################################")
    # 主題-詞語分佈矩陣
    print(lda.components_)
    # 印出每個主題下權重教中的字詞
    for topic_idx, topic in enumerate(lda.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-20 - 1:-1]]))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# [[3.92156863e-05 3.92156863e-05 3.92156863e-05 ... 3.92156863e-05
#   3.92156863e-05 3.92156863e-05]
#  [7.35294118e-05 7.35294118e-05 7.35294118e-05 ... 7.35294118e-05
#   7.35294118e-05 7.35294118e-05]
#  [6.36942675e-05 6.36942675e-05 6.36942675e-05 ... 6.36942675e-05
#   6.36942675e-05 6.36942675e-05]
#  ...
#  [6.89655172e-05 6.89655172e-05 6.89655172e-05 ... 6.89655172e-05
#   6.89655172e-05 6.89655172e-05]
#  [5.52486188e-05 5.52486188e-05 5.52486188e-05 ... 5.52486188e-05
#   5.52486188e-05 5.52486188e-05]
#  [7.57575758e-05 7.57575758e-05 7.57575758e-05 ... 7.57575758e-05
#   7.57575758e-05 7.57575758e-05]]
# [[0.01 0.01 0.01 ... 0.01 0.01 0.01]
#  [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#  [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#  ...
#  [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#  [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#  [0.01 0.01 0.01 ... 0.01 0.01 0.01]]
# Topic #0:
# 亞洲 公司 雷明頓 季後賽 金酒 防守 晉級 資格賽 菲律賓 葉門 表示 隊史 取得 吉斯 吉爾 機會 槍擊案 億元 台幣 生產
# Topic #1:
# 兩岸 通貨膨脹 民眾 希望 台灣 利率 表示 房價 設計 歡迎 地方 主任 合作 交流 房市 司機 劉結 是否 發展 記者
# Topic #2:
# 明哲 鞋款 海基 職業 台灣 camper 選手 去年 報導 今年 張睿家 戀人 監獄 探視 世界 表示 動物系 日本 女生 發現
# Topic #3:
# 市場 億元 成長 季後賽 台北 今年 交易 達爾膚 去年 記者 董事 頂級 營收 營運 電商 投資 持續 首戰 布拉 高力
# Topic #4:
# 公斤 都城 鯨魚 彩券 表示 報導 動物 巴黎 生活 萬元 最大 阿達 台幣 杭州 文化 亞錦賽 洪幼婷 金元 得分 水中
# Topic #5:
# 玩具 親子 研究 兩岸 措施 文化 合作 airpods 台灣 李文 人員 踢球 訴訟 報導 指出 李敖 細菌 中心 台胞 落實
# Topic #6:
# 李紀珠 服務 藥物 報導 新光 治療 表示 環境 環評 管理 要求 吳欣盈 總經理 進入 家族 民眾 指出 提供 部分 影響
# Topic #7:
# 野餐 男子 博物 聯盟 影片 中心 男童 摩洛哥 一名 表示 海洋 國會 國際 綜合 地址 海景 公園 南北 代表 大會
# Topic #8:
# 德國 巴西 持續 戈麥茲 此役 雖然球 軍陣容 兵敗 子弟兵 成功 擺上 德國隊 柏林 boateng 中後衛博 kevin 兩大 給德國 willian 阿滕
# Topic #9:
# 台灣 發展 大陸 峰山 同胞 llb 棒球 台獨 世界 兩岸 經濟 階段 申請 聯盟 兩岸關 幼棒 協會 幼兒 super 甄選委員會
# Topic #10:
# 血管 毛毛 表示 身材 開槍 支持 林口 疾病 警方 鄭明輝 醫院 警察 上圍 小孩 年紀 手術 媽媽 特勤 剛出 楊丞琳
# Topic #11:
# 機長 直播 航班 急救 一名 胡志明市 無效 越南 飛往 事故 時間 昏迷 華航 駕駛 中正 機場 女子 露出 手術 整型
# Topic #12:
# 工作 運勢 日本 感情 生活 津端 電影 財運運勢 市長 夫人 時間 美國 修一 中國 櫻花 人生 積存 夫婦 投資 英子
# Topic #13:
# 受刑人 兒童 限量 教誨 藝術 闖關 清明 論文 週刊 廖瑞坤 研究 入園 中心 推出 園區 小朋友 宜蘭 報導 體驗 傳統
# Topic #14:
# 商場 男子 江辰 中心 普丁 報導 表示 工作 警方 火災 這場 法拉利 今年 當地 死亡 調查 昨日 造成 前往 受害者
# Topic #15:
# 工作 表示 鞋子 司法 小平 性別 報導 公司 夜景 平等 錄取 同學 嘉藥 國民黨 徵才 李錫錕 台北 台北市 大一點 提供
# Topic #16:
# 外野 台北 報導 山東 陣型 北捷 購屋 發生 減少 太空 指出 捷運 青島 失去 旅遊 增加 症狀 春訓 左外野 打者
# Topic #17:
# 毒品 包裹 表示 唾液腺 現在 out in 指出 綜合 影片 團體 囊腫 漢堡 造成 記者 反毒 企業 藥頭 嘴唇 白紙
# Topic #18:
# 父親 大陸 報導 表示 記者 網友 金融 蔡宜 中心 公然侮辱 知道 萬德友 呱呱 台灣 工作 生活 希望 消息 認為 侮辱
# Topic #19:
# 英雄 胸部 節目 無限之戰 漫威 聯盟 仇者 英文 報導 角色 霍思燕 兩人 表示 指出 團隊 經濟 行政 撤告 台灣 網友
# Topic #20:
# 銀行 報導 表示 發現 男童 nxivm 貸款 記者 時間 工作 歐陽大智 新光 林女 指出 成功 司機 法拉利 處理 警方 事情
# Topic #21:
# 瑞典 台灣 受刑人 表示 少年 報導 名稱 受害者 喬許 綜合 赫德 外交部 性侵 哈利波 使用 一名 中心 意外 公告 國稅局
# Topic #22:
# 前妻 上映 意外 等級 保障 男子 職業 發生 友邦 小琳 報導 戰警 隨即 未遂 台北 表示 手術 高院 醫療 萬元
# Topic #23:
# 台灣 王維中 小孩 半部 溝通 日本 大聯盟 報導 未來 av 公公 新人 片商 表示 韓職 生涯 成為 偶像 每天 一名
# Topic #24:
# 醫務 社工 南山 工作 慈善 基金 全台 人壽 專業 醫療 提供 欺負 一起 英宗 團隊 獲獎 表揚 單位 福利部 第一
# Topic #25:
# apple 川崎 女兒 ipad 報導 平板 南海 隋棠 宣布 解放 大隊 前往 台灣 表示 公司 推出 不吃 記者 達比修 pencil
# Topic #26:
# 氣象 合作 表示 基金 領域 網路 投資 pchome 台灣 中華電 一審 環境 氣象局 市府 遊客 農業 北京市 宣判 護理師 中華
# Topic #27:
# 可麗餅 辻利 犬貓 法式 花園 毛孩 推出 省油 km 技術 gelato pique 豬排 最新 送養 報導 bluemotion 車輛 福斯 滑行
# Topic #28:
# 兄弟 民進 台灣 表示 報導 國民黨 記者 伊斯 獅隊 台北 完成 提名 月光 西班牙 活動 周思齊 中信 綜合 遊客 之前
# Topic #29:
# 台電 號機 安全 原能會 核二廠 提出 美國 停機 原因 綜合 報告 核准 貿易 張中生 核二 測試 反應 發生 聯發電 同意
# Topic #30:
# 盈潔 台北 影片 報導 表示 共識 大陸 朱立倫 九二 本票 綜合 管道 國民黨 中國 台獨 共同 問題 兩岸 交流 中心
# Topic #31:
# 公布 試題 金正恩 乘坐 火車 專屬 中式 fii 列車 考題 選擇 金正日 分析 考試 美食 飛機 答案 測驗 考生 表示
# Topic #32:
# 海芋 竹子湖 搭乘 停車場 社區 轉乘 公車 演唱 楊宗緯 第二 卵子 頂湖 紐約 工作 首歌 大道 明山 崔西 報導 觀眾
# Topic #33:
# 支付 使用者 去年 表示 街口 今年 台灣 多元 規劃 未來 報導 帳戶 問題 搭乘 文化 喜門史 塔雷 中共 無法 集團
# Topic #34:
# 健康 族群 aqi 大學 活動 楊丞琳 指標 所有 丞琳 記者 報導 合作 環保局 防部 rotc 生活 之等級 伸展 警示 演唱
# Topic #35:
# 調漲 民眾 騎士 合作 薪水 表示 沈榮津 感受 詹姆斯 韋德 感覺 希望 一起 報導 日本 哈娜 回應 影響 再次 克里夫
# Topic #36:
# 龜山島 宗德 完美 完花 完豬 完賽 完雞 完餐 宏偉 宏志 宏泰人壽 宏碁 宏竹里 宗則 宗教 宋仲基 宗旨 官位 官何 官僚
# Topic #37:
# 至少 超過 喜歡 朋友 每天 要求 特別 白色 金正恩 風格 店家 知道 報告 桃園 模擬 李雪主 中國 衣服 模特 每周
# Topic #38:
# 研究 中心 反應 報導 表示 設施 計畫 科技部 科技 補助 台灣 良基 飢餓 遊戲 發展 教授 治療 軀體 台大 家人
# Topic #39:
# 燃料 hyundai 律師 醫院 nexo 女生 智慧 醫療 宏碁 表示 韓國 話術 證人 約合 電池 合作 電池車 公里 醫學大學 韓元
# Topic #40:
# 台灣 智慧 物聯網 iot 平台 資料 全球 水壺 網路 提供 入祀 馮世寬 安娜 nb 物聯 之星 ai 城市 服務 報導
# Topic #41:
# 排伯 華航 國稅局 表示 小時 時間 家屬 航班 登記 原因 同仁 送醫 檢舉 輔導 自殺 休時 對華航 機師 事件 飛時
# Topic #42:
# 護理 台幣 萬韓 座位 胖子 女性 澳洲 健康 癲癇 報導 表示 症狀 工作 組織 婦女 分院 人員 尼泊爾 品質 綜合
# Topic #43:
# 貨幣 數位 日本 比特 交易 交易所 金融 林太太 時間 便當 兄弟 表示 投資人 指出 銀行 威助 提供 決選 中信 hoya
# Topic #44:
# 蟑螂 電視 周小潔 頻道 食物 ncc 合約 無線 表示 已經 部分 環境 結算 活動 保持 衛星 民進 規定 認為 生活
# Topic #45:
# 平潭 客房 大千 svr 台北 台灣 推出 報導 rgb pace 台商 記者 遊戲 服務 漲幅 表示 全面 當地 玩家 幻焰
# Topic #46:
# 李紀珠 大陸 創業 新光 機會 台灣 表示 認為 台青 騎士 市場 友人 人才 企業 董事 報導 措施 詹姆斯 政策 去年
# Topic #47:
# 小行星 金正恩 地球 miu 表示 大溪 軌道 天體 天文 照片 報導 近地 女警 小姐 川普 蘇佩霞 推出 中心 綜合 少女
# Topic #48:
# 台北 表示 車站 朴槿惠 報告 app 上線 旅客 燃料 飛機 飛行 記者 事故 金章洙 捷運 侯友宜 政府 民調 航空 報導
# Topic #49:
# 遺體 金正恩 香港 表示 報導 台灣 中國 北京 大谷 希望 北韓 習近 許維恩 外界 中心 美國 大聯盟 開幕 直接 法國
# Topic #50:
# 台灣 壓力 阿比 vr 伊斯 playstation 主席 手術 報導 記者 旅行 發展 兩國 救援 賴清德 國際 鈕則 世代 調查 無法
# Topic #51:
# 女兒 保險法 簡易 一名 潔絲敏 報導 保費 人壽 契約 知道 女孩 莉雅 瓦萊 表示 網友 男子 中華郵政 小朋友 基金 演員
# Topic #52:
# 驅逐 降稅 冰品 外交官 英國 宣布 進行 億元 主席 俄羅斯 美國 歐盟 國民黨 金管會 增加 報告 表決 提案 售價 影響
# Topic #53:
# 打擊率 中信 兄弟 打者 美國隊 統一獅 報導 系統 測試 角色 賠率 面對 防禦率 熱身賽 告警 威脅 戴利 離開 聯盟 里奇
# Topic #54:
# 美元 金融 報導 工作 表示 綜合 蘋果 中心 勇士 公司 提出 劉鶴 改革 提高 大聯盟 今天 發展 指出 報價 合約
# Topic #55:
# 台灣 美國 北京 大陸 當局 館長 方式 兩岸 台灣牌 軍艦 服務 護欄 安平 顏歆 女警 表示 男子 政策 想到 引起
# Topic #56:
# 安定 活動 吳鳳 新加坡 和平 中央 咖啡 地址 ty 書記 國家 委員 中共中央政治局 實現 首次 李雪主 作用 近平 鹿角菜 使用
# Topic #57:
# 總統 緬甸 啤酒 溫敏 酒標 選舉 議員 蘇姬 聯名 翁山 成為 本名 女兒 議會 台灣 報導 代表 賈靜雯 品牌 屋頂
# Topic #58:
# 金泰 睫毛 自然 眉毛 少女 rain 每次 完美 辦法 斯容 整到 刷牙 外貌 綜合 報導 女神 選擇 小時候 自拍照 不想
# Topic #59:
# 各地 半部 氣象局 林宜青 山區 記者 台北 機率 表示 mastro 報導 宜青 公斤 美國 北部 塔柱 相片 亞錦賽 作品 比賽
# Topic #60:
# 國安局 羊乳 調查 台南市 中心 網路 發現 英文 事件 特勤 投資 夫婦 列車 蕭婦 萬元 表示 奶粉 監視器 畫面 報導
# Topic #61:
# 金正恩 北韓 北京 習近 美國 加油站 官方 桑德斯 員工 大陸 相關 訪問 鮮半島 核化 證實 警方 準備 造成 安全 密訪
# Topic #62:
# 玩家 廉政 道路 遊戲 新竹市 八卦 對方 品質 工程 探索 劇情 養成 任務 市府 今年 表示 抉擇 變化 當天 大兵
# Topic #63:
# 北海道 美國 pass 金正恩 jr 制服 北韓 麥克 無頭 札幌 富良野 日本 北京 中國 全國版 兌換 訪問 上野 美瑛 中華郵政
# Topic #64:
# 眼中 圖片 車主 還不趕 車主們 幾分 以上 路上 是否 媒體 特色 教室 明開 身旁 不能不要 回事 鐘義務 車的 車種 分別
# Topic #65:
# 台灣 豆腐乳 狗狗 報導 理事 吳小暉 胡志明市 月亮 表示 航線 開通 台北 安邦 天文 銷售 rover 越捷 骨頭 品牌 land
# Topic #66:
# 時間 記者 報導 自來 大谷 人輪值 重要 先發 亞運 男足 水質 消防人 弟弟 表示 選擇 準備 消防局 投手 希望 綜合
# Topic #67:
# 發展 習近 金正恩 表示 兩國 雙方 中朝 中國 兩黨 同志 主席 傳統 半島 共同 重要 人民 形勢 問題 友誼 作出
# Topic #68:
# 新竹 左岸 天宮 一號 改善 出入口 太空 台灣 墜落 工程 動線 地球 中國 環境 報導 新竹市 自行 空間 運動 指出
# Topic #69:
# 今年 國際 粉餅 奧會 公投 重要 使用 間質 器官 bii 粉刺 搭配 奧運 中華 車輛 引擎 李玉璽 報導 我國 肌膚
# Topic #70:
# 餐廳 米其林 徵才 球員 就業 三星 台灣 足球 人才 醫院 希望 中華 懷特 表示 報導 博覽會 值得 登記 畢業 重要
# Topic #71:
# 表示 歐盟 導彈 資料 董事 報導 中國 進口 人民 億元 貿易局 臉書 街口 支付 無人機 措施 日本 公告 市場 影響
# Topic #72:
# 新光 公司 重工 應急 要求 起薪 萬元 人壽 登高 合作 銀行 活動 臉書 契約 顧立雄 表示 總經理 泰國 項目 中船
# Topic #73:
# 報導 雕像 hovr 兩人 一名 表示 警方 北韓 愛心 記者 阿翔 跑步 浩子 清明 網友 發售 學生 粉末 美元 疑似
# Topic #74:
# 董事 吳音寧 台北市 北農 柯文 報導 警方 景峻 中心 問題 瘋狂 休市 農委會 政治 丁守中 台北 表示 男子 綜合 毒品
# Topic #75:
# 自殺 學生 混齡 教學 若熙 老師 合約 希望 課程 教育部 偏鄉 寶山國 程度 教育 沃斯 報導 犧牲 教材 工作 實驗
# Topic #76:
# 巨人 公司 政治 遊戲 已經 台北 記者 報導 利益 柯文 表示 詹順貴 推出 吳音寧 捕食 模式 網友 玩家 禁賽 達欣
# Topic #77:
# 深澳 adidas 回家 表示 行政院 電廠 李易峰 影響 喬志 粉絲 報導 和平 綜合 記者 居民 弟弟 堅持 健康 被告 加入
# Topic #78:
# 汽車 品牌 購買 記者 網友 投保 網路 台灣 地球 報導 兄弟 局上 電視 出局 形成 bmw 萬元 美國 飛球 南韓
# Topic #79:
# 雙方 愛家 廣中 利益 毛孩 駱志偉 認為 真的 惡童 最大 手機 談判 表示 改變 核心 變得 一拿起 當低 頭族 撒嬌
# Topic #80:
# 進食 報導 中國 企鵝 國王 表示 導彈 台灣 美國 石女 東風 猥褻 蘇玥 台北 身體 娃娃 房間 戰機 戰鬥機 換羽期
# Topic #81:
# 龜山島 宗德 完美 完花 完豬 完賽 完雞 完餐 宏偉 宏志 宏泰人壽 宏碁 宏竹里 宗則 宗教 宋仲基 宗旨 官位 官何 官僚
# Topic #82:
# 基金 跌幅 輕人 基富通 金正恩 投資人 定期 定額 市場 金正日 超過 報導 透過 方式 基富 搭乘 飛機 大跌 一些 認為
# Topic #83:
# 地震 桃園 台灣 發生 主席 規模 伊斯 洛杉磯 公里 名譽 會長 商會 南澳 報導 表示 有感 深度 男童 宜蘭 晚間
# Topic #84:
# 好球 投手 今年 表示 金正恩 打者 認為 適應 左右 川普 北韓 中國 休息室 增加 比較 比賽 角球 記者 報導 顯示
# Topic #85:
# 生育 美國 計劃 表示 瑪莉朴 公主 報導 開發 聯合會 迪士尼 總經理 虐待 中鋼 地熱 聯盟 rs 父母 男人 全新 調查
# Topic #86:
# running man 鬼怪 韓國 優惠 人半價 體驗館 任務場 遊客 附近 逛個夠 台北 還要 韓劇 天天 線上 萬元 春季 三清 最激
# Topic #87:
# 郵局 保全 監測 系統 異常 atm 發現 現象 遠端 處理 分鐘 單位 發出 安全 狀況 超過 通知 柔性 全台 情形
# Topic #88:
# 金正恩 北京 鏡頭 照片 手機 記者 拍攝 習近 報導 pro 萬畫素 北韓 效果 拍照 ais ai 黑白 手抖 實測 光圈
# Topic #89:
# 咖啡 桃園 角後院 民調 國民黨 市長 楊麗環 帽子 女兒 明哲 現任 立委 基隆 活節 新人 中正 表示 喜歡 生活 自轉
# Topic #90:
# 大s 狀況 經紀 表示 身體 希望 鄭仲茵 得知 報導 網友 孕吐 ettoday 空間 懷孕 嚴重 星光 情況 已經 真的 動作
# Topic #91:
# 計畫 航空 桃園 都市 報導 表示 範圍 記者 丁小芹 市府 市政府 城計畫 跑道 第三 郭振堂 熱量 台電 ipad 能夠 附近
# Topic #92:
# kids 公司 stray 提名 林口 kid jyp 民眾 報導 團體 歌曲 習生 rap 提供 岳父 立委 台北 記者 han 有限公司
# Topic #93:
# 治療 乳癌 海芋 基因 病人 棺木 報導 時間 眉毛 木乃伊 寶佳 琳娜 郭玟 輔助 接受 指出 選擇 發現 眉型 氣質
# Topic #94:
# 報導 機會 張力 希望 教育 記者 演員 對方 孩童 要求 電影 蘇志燮 保全 被告 中心 綜合 造成 室友 接受 表示
# Topic #95:
# 數據 行政院 綠色 研究 聯盟 深澳 公民 電廠 女子 男童 留言 中心 行動 指出 吳澄澄 略低 居民 影片 發現 基金
# Topic #96:
# 拆除 帳篷 申請 八百 壯士 建管 攤棚 台北市 通知 公投 路權 報備 記者 空手道 自行 報導 立法院 中山南路 市府 柯文
# Topic #97:
# 雞肉 台灣 簡單 投保 給付 民眾 肉片 保障 增長 旅遊 男友 表示 價格 萬元 中新網 傷害 費用 專案 商品 國內
# Topic #98:
# 地址 大阪府 大阪市 中央区 阿根廷 西班牙 台灣 眼睛 斎橋 分鐘 使用 提供 難波 日前 懷特 梅西 足球 淚液 記者 報導
# Topic #99:
# 文豪 中心 退伍 報導 特斯拉 當時 蘋果 官邸 總統 美元 特勤 英文 分析 警衛官 表示 去年 永和 事件 王姓 內部
